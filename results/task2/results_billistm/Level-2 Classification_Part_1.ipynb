# %% [markdown]
# ### Models Included
# - SVM
# - Bi-LSTM
# - BiLSTM with Attention
# - LSTM CNN

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, SimpleRNN, Flatten,\
Activation, RepeatVector, Permute, Concatenate, Lambda
#from tensorflow_addons.layers import CRF  # Assuming you're using TensorFlow Addons for CRF
from tensorflow.keras import optimizers
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import random
import subprocess
from sklearn.utils import class_weight
import tensorflow.keras.backend as K
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Multiply
from tensorflow.keras.layers import Conv1D, MaxPooling1D

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Move two levels up
grandparent_directory = os.path.abspath(os.path.join(current_directory, "..", "..", ".."))

# Specify the folder name
folder_name = "data"

# Combine the grandparent directory with the folder name
folder_path = os.path.join(grandparent_directory, folder_name)

# List files in the specified folder
files = os.listdir(folder_path)

# Select the "Task2.csv" file
task2_file = "Task2.csv"

if task2_file in files:
    print(f"The '{task2_file}' file is present in the '{folder_name}' folder.")
else:
    print(f"The '{task2_file}' file is not found in the '{folder_name}' folder.")

file_path=os.path.join(folder_path,task2_file)

print(f"The file path is {file_path}")
# Out:
# The 'Task2.csv' file is present in the 'data' folder.
# The file path is c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\data\Task2.csv

# %%
data = pd.read_csv(file_path)
data = data.rename(columns={'id':'Sentence #'})
data = data.dropna(axis=0)
#data = data.drop('Unnamed: 0',axis=1)

# %%
data.groupby('type').count()
# Out:
#       sentence_id  sentence  category
# type
# E            1129      1129      1129
# I            1174      1174      1174

# %%
data
# Out:
#       sentence_id                                           sentence  \
# 0               0  late afternoon a very hot day which took some ...
# 1               1                        concessions were overpriced
# 2               2                                queues were minimal
# 3               3                of truly healthy options for dining
# 4               4                       park entry fee is reasonable
# ...           ...                                                ...
# 2298         2151                                        in the rain
# 2299         2152                             without feeling pushed
# 2300         2152                                     claustrophobic
# 2301         2152                                   hordes of crowds
# 2302         2153                                         our family
#
#             category type
# 0     time/day/month    E
# 1              price    E
# 2             queues    I
# 3               food    E
# 4              price    I
# ...              ...  ...
# 2298  time/day/month    E
# 2299           crowd    I
# 2300  claustrophobic    E
# 2301           crowd    E
# 2302  couples/family    I
#
# [2303 rows x 4 columns]

# %%
sentences = []
labels = list(data['type']) 
typs = data['type'].values #Spelling error, there was it was types not type
x = data.apply(lambda l: sentences.append(l['sentence'].split(' ')),axis=1)

# %%
words = []
for sent in sentences:
    for wrd in sent:
        words.append(wrd)
words = list(set(words))
tags = list(set(labels))

n_words = len(words)
n_tags = len(tags)

# %%
len(typs)
# Out:
# 2303

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
max_len = 30
X = [[word2idx[w] for w in s] for s in sentences]    
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=0)
y = [tag2idx[tg] for tg in labels]
# y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])
y = np.array([to_categorical(i, num_classes=n_tags) for i in y])
y = [[y[i],typs[i]] for i in range(len(y))]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

y_train = np.array([lab[0] for lab in y_train])
typ_test = [lab[1] for lab in y_test]
y_test = np.array([lab[0] for lab  in y_test])

# %%
# def loadGloveModel(File):
#     print("Loading Glove Model")
#     f = open(File,'r')
#     gloveModel = {}
#     for line in f:
#         splitLines = line.split()
#         word = splitLines[0]
#         wordEmbedding = np.array([float(value) for value in splitLines[1:]])
#         gloveModel[word] = wordEmbedding
#     print(len(gloveModel)," words loaded!")
#     return gloveModel

# vec_model = loadGloveModel('glove/glove.6B.200d.txt')

# %%
def loadGloveModel(File):
    with open(File, 'r', encoding='utf-8') as f:
        gloveModel = {}
        for line in f:
            splitLines = line.split()
            word = splitLines[0]
            wordEmbedding = np.array([float(val) for val in splitLines[1:]])
            gloveModel[word] = wordEmbedding
    print(len(gloveModel), "words loaded!")
    return gloveModel

vec_model = loadGloveModel('glove/glove.6B.200d.txt')
# Out:
# 400000 words loaded!

# %%
emb_dim = len(vec_model['the'])
embedding_matrix = np.zeros((len(word2idx) + 1, emb_dim))

for word, i in word2idx.items():
    if word not in vec_model:
        continue
    embedding_vector = vec_model[word]
    embedding_matrix[i] = embedding_vector

print(embedding_matrix.shape)
# Out:
# (1894, 200)

# %%
def full_results(y_test,pred):
    
    report = classification_report(y_test,pred.flatten('F'),output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    
    inc_test = []
    exc_test = []
    inc_pred = []
    exc_pred = []
    for i,t in enumerate(typ_test):
        if t == 'I':
            inc_test.append(y_test[i])
            inc_pred.append(pred[i])
        else:
            exc_test.append(y_test[i])
            exc_pred.append(pred[i])
    print("For inclusions")
    report = classification_report(inc_test,inc_pred,output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    print("For exclusions")
    report = classification_report(exc_test,exc_pred,output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    return

def return_report(model,epochs):
    y_flat = list(np.argmax(y_test,1).flatten('F'))
#     class_weights = class_weight.compute_class_weight('balanced',y_flat)
#     class_weights = [1,10,20,10,20]
    model.fit(X_train,y_train,epochs=epochs,verbose=1)
    out = model.predict(X_test)
    pred = np.argmax(out,1)
    full_results(y_flat,pred)
    return pred

# %%
def get_bilstm_lstm_model():
    
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)

    # Add bidirectional LSTM
    model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)    
    
    model = TimeDistributed(Dense(100,activation='relu'))(model)
    model = Flatten()(model)
    model = Dense(100,activation='relu')(model)
    # Add timeDistributed Layer
    out = Dense(n_tags, activation="softmax")(model)

    #Optimiser 
    adam = Adam(lr=0.0007)

    # Compile model
    model = Model(input, out)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    
    return model

def lstm_attention():
    
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)

    # Add bidirectional LSTM
    model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)

    attention = TimeDistributed(Dense(1, activation='tanh'))(model) 
    attention = Flatten()(attention)
    attention = Activation('softmax')(attention)
    attention = RepeatVector(2*emb_dim)(attention)
    attention = Permute([2, 1])(attention)

    # apply the attention
    sent_representation = Multiply()([model, attention])
    sent_representation = Lambda(lambda xin: K.sum(xin, axis=1))(sent_representation)
    probabilities = Dense(3, activation='softmax')(sent_representation)
    
    # Add timeDistributed Layer
    out = Dense(n_tags, activation="softmax")(sent_representation)

    #Optimiser 
    adam = Adam(lr=0.0007)

    # Compile model
    model = Model(input, out)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    
    return model

def lstm_cnn():
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)
    model = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu')(model)
    model = MaxPooling1D(pool_size=2)(model)
    model = LSTM(100,dropout=0.2,recurrent_dropout=0.2)(model)
    out = Dense(n_tags, activation='softmax')(model)
    model = Model(input,out)
    adam = Adam(lr=0.0007)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    print(model.summary())
    
    return model

# %%
# from keras.layers import InputLayer

# def get_bilstm_lstm_model():
    
#     input_layer = Input(shape=(max_len,))

#     # Add Embedding layer
#     model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
#                   input_length=max_len, weights=[embedding_matrix], trainable=False)(input_layer)

#     # Add bidirectional LSTM
#     model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)    
    
#     model = TimeDistributed(Dense(100, activation='relu'))(model)
#     model = Flatten()(model)
#     model = Dense(100, activation='relu')(model)
#     # Add timeDistributed Layer
#     out = Dense(n_tags, activation="softmax")(model)

#     # Optimizer 
#     adam = ko.Adam(lr=0.0007)

#     # Compile model
#     model = Model(input_layer, out)
#     model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#     model.summary()
    
#     return model

# %%
bilistm = get_bilstm_lstm_model()
pred = return_report(bilistm,25)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 30)]              0
#
#  embedding_2 (Embedding)     (None, 30, 200)           378800
#
#  bidirectional_2 (Bidirecti  (None, 30, 400)           641600
#  onal)
#
#  time_distributed_2 (TimeDi  (None, 30, 100)           40100
#  stributed)
#
#  flatten_2 (Flatten)         (None, 3000)              0
#
#  dense_7 (Dense)             (None, 100)               300100
#
#  dense_8 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 1360802 (5.19 MB)
# Trainable params: 982002 (3.75 MB)
# Non-trainable params: 378800 (1.45 MB)
# _________________________________________________________________
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 58/58 [==============================] - 13s 113ms/step - loss: 0.5676 - accuracy: 0.7177
# Epoch 2/25
# 58/58 [==============================] - 6s 111ms/step - loss: 0.4406 - accuracy: 0.7953
# Epoch 3/25
# 58/58 [==============================] - 7s 115ms/step - loss: 0.3751 - accuracy: 0.8333
# Epoch 4/25
# 58/58 [==============================] - 7s 112ms/step - loss: 0.3400 - accuracy: 0.8540
# Epoch 5/25
# 58/58 [==============================] - 6s 111ms/step - loss: 0.2547 - accuracy: 0.8985
# Epoch 6/25
# 58/58 [==============================] - 7s 116ms/step - loss: 0.1952 - accuracy: 0.9229
# Epoch 7/25
# 58/58 [==============================] - 6s 110ms/step - loss: 0.1692 - accuracy: 0.9370
# Epoch 8/25
# 58/58 [==============================] - 6s 111ms/step - loss: 0.1375 - accuracy: 0.9522
# Epoch 9/25
# 58/58 [==============================] - 7s 116ms/step - loss: 0.1175 - accuracy: 0.9511
# Epoch 10/25
# 58/58 [==============================] - 6s 108ms/step - loss: 0.1003 - accuracy: 0.9615
# Epoch 11/25
# 58/58 [==============================] - 6s 110ms/step - loss: 0.0727 - accuracy: 0.9788
# Epoch 12/25
# 58/58 [==============================] - 7s 117ms/step - loss: 0.0500 - accuracy: 0.9843
# Epoch 13/25
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0437 - accuracy: 0.9864
# Epoch 14/25
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0617 - accuracy: 0.9799
# Epoch 15/25
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0502 - accuracy: 0.9815
# Epoch 16/25
# 58/58 [==============================] - 8s 130ms/step - loss: 0.0420 - accuracy: 0.9837
# Epoch 17/25
# 58/58 [==============================] - 7s 125ms/step - loss: 0.0310 - accuracy: 0.9891
# Epoch 18/25
# 58/58 [==============================] - 7s 122ms/step - loss: 0.0308 - accuracy: 0.9902
# Epoch 19/25
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0190 - accuracy: 0.9951
# Epoch 20/25
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0156 - accuracy: 0.9940
# Epoch 21/25
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0161 - accuracy: 0.9957
# Epoch 22/25
# 58/58 [==============================] - 6s 109ms/step - loss: 0.0215 - accuracy: 0.9929
# Epoch 23/25
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0327 - accuracy: 0.9864
# Epoch 24/25
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0294 - accuracy: 0.9875
# Epoch 25/25
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0172 - accuracy: 0.9935
# 15/15 [==============================] - 1s 19ms/step
#               precision    recall  f1-score     support
# 0              0.818966  0.883721  0.850112  215.000000
# 1              0.890830  0.829268  0.858947  246.000000
# accuracy       0.854664  0.854664  0.854664    0.854664
# macro avg      0.854898  0.856495  0.854530  461.000000
# weighted avg   0.857314  0.854664  0.854827  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.883721  0.938272  215.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.883721  0.883721  0.883721    0.883721
# macro avg      0.500000  0.441860  0.469136  215.000000
# weighted avg   1.000000  0.883721  0.938272  215.000000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.000000  0.000000  0.000000    0.000000
# 1              1.000000  0.829268  0.906667  246.000000
# accuracy       0.829268  0.829268  0.829268    0.829268
# macro avg      0.500000  0.414634  0.453333  246.000000
# weighted avg   1.000000  0.829268  0.906667  246.000000

# %%
attn = lstm_attention()
preds = return_report(attn,50)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_3 (Embedding)     (None, 30, 200)              378800    ['input_4[0][0]']
#
#  bidirectional_3 (Bidirecti  (None, 30, 400)              641600    ['embedding_3[0][0]']
#  onal)
#
#  time_distributed_3 (TimeDi  (None, 30, 1)                401       ['bidirectional_3[0][0]']
#  stributed)
#
#  flatten_3 (Flatten)         (None, 30)                   0         ['time_distributed_3[0][0]']
#
#  activation (Activation)     (None, 30)                   0         ['flatten_3[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 400, 30)              0         ['activation[0][0]']
#  r)
#
#  permute (Permute)           (None, 30, 400)              0         ['repeat_vector[0][0]']
#
#  multiply (Multiply)         (None, 30, 400)              0         ['bidirectional_3[0][0]',
#                                                                      'permute[0][0]']
#
#  lambda (Lambda)             (None, 400)                  0         ['multiply[0][0]']
#
#  dense_11 (Dense)            (None, 2)                    802       ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1021603 (3.90 MB)
# Trainable params: 642803 (2.45 MB)
# Non-trainable params: 378800 (1.45 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 58/58 [==============================] - 12s 115ms/step - loss: 0.5869 - accuracy: 0.6895
# Epoch 2/50
# 58/58 [==============================] - 6s 110ms/step - loss: 0.4873 - accuracy: 0.7752
# Epoch 3/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.4492 - accuracy: 0.7910
# Epoch 4/50
# 58/58 [==============================] - 6s 110ms/step - loss: 0.4168 - accuracy: 0.8067
# Epoch 5/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.4086 - accuracy: 0.8035
# Epoch 6/50
# 58/58 [==============================] - 6s 110ms/step - loss: 0.3643 - accuracy: 0.8426
# Epoch 7/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.3193 - accuracy: 0.8534
# Epoch 8/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.3160 - accuracy: 0.8632
# Epoch 9/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.2699 - accuracy: 0.8887
# Epoch 10/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.2700 - accuracy: 0.8876
# Epoch 11/50
# 58/58 [==============================] - 7s 122ms/step - loss: 0.2684 - accuracy: 0.8865
# Epoch 12/50
# 58/58 [==============================] - 8s 129ms/step - loss: 0.2389 - accuracy: 0.9077
# Epoch 13/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.2448 - accuracy: 0.9023
# Epoch 14/50
# 58/58 [==============================] - 7s 112ms/step - loss: 0.2365 - accuracy: 0.9055
# Epoch 15/50
# 58/58 [==============================] - 7s 123ms/step - loss: 0.1677 - accuracy: 0.9403
# Epoch 16/50
# 58/58 [==============================] - 7s 124ms/step - loss: 0.1467 - accuracy: 0.9446
# Epoch 17/50
# 58/58 [==============================] - 7s 126ms/step - loss: 0.1580 - accuracy: 0.9408
# Epoch 18/50
# 58/58 [==============================] - 7s 112ms/step - loss: 0.1411 - accuracy: 0.9490
# Epoch 19/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.1477 - accuracy: 0.9463
# Epoch 20/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.1135 - accuracy: 0.9620
# Epoch 21/50
# 58/58 [==============================] - 7s 121ms/step - loss: 0.1009 - accuracy: 0.9631
# Epoch 22/50
# 58/58 [==============================] - 7s 129ms/step - loss: 0.1067 - accuracy: 0.9625
# Epoch 23/50
# 58/58 [==============================] - 7s 120ms/step - loss: 0.1205 - accuracy: 0.9571
# Epoch 24/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0813 - accuracy: 0.9745
# Epoch 25/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0789 - accuracy: 0.9772
# Epoch 26/50
# 58/58 [==============================] - 7s 128ms/step - loss: 0.0599 - accuracy: 0.9756
# Epoch 27/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0686 - accuracy: 0.9783
# Epoch 28/50
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0514 - accuracy: 0.9821
# Epoch 29/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0457 - accuracy: 0.9837
# Epoch 30/50
# 58/58 [==============================] - 7s 119ms/step - loss: 0.0380 - accuracy: 0.9881
# Epoch 31/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0412 - accuracy: 0.9875
# Epoch 32/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0416 - accuracy: 0.9886
# Epoch 33/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0263 - accuracy: 0.9908
# Epoch 34/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0266 - accuracy: 0.9913
# Epoch 35/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0227 - accuracy: 0.9924
# Epoch 36/50
# 58/58 [==============================] - 6s 109ms/step - loss: 0.0224 - accuracy: 0.9935
# Epoch 37/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0470 - accuracy: 0.9832
# Epoch 38/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0687 - accuracy: 0.9794
# Epoch 39/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0338 - accuracy: 0.9881
# Epoch 40/50
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0277 - accuracy: 0.9913
# Epoch 41/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0206 - accuracy: 0.9951
# Epoch 42/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0213 - accuracy: 0.9940
# Epoch 43/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0146 - accuracy: 0.9957
# Epoch 44/50
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0154 - accuracy: 0.9951
# Epoch 45/50
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0316 - accuracy: 0.9919
# Epoch 46/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0278 - accuracy: 0.9908
# Epoch 47/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0160 - accuracy: 0.9962
# Epoch 48/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0135 - accuracy: 0.9967
# Epoch 49/50
# 58/58 [==============================] - 7s 114ms/step - loss: 0.0171 - accuracy: 0.9957
# Epoch 50/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0222 - accuracy: 0.9935
# 15/15 [==============================] - 1s 23ms/step
#               precision    recall  f1-score     support
# 0              0.813043  0.869767  0.840449  215.000000
# 1              0.878788  0.825203  0.851153  246.000000
# accuracy       0.845987  0.845987  0.845987    0.845987
# macro avg      0.845916  0.847485  0.845801  461.000000
# weighted avg   0.848126  0.845987  0.846161  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.869767  0.930348  215.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.869767  0.869767  0.869767    0.869767
# macro avg      0.500000  0.434884  0.465174  215.000000
# weighted avg   1.000000  0.869767  0.930348  215.000000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.000000  0.000000  0.000000    0.000000
# 1              1.000000  0.825203  0.904232  246.000000
# accuracy       0.825203  0.825203  0.825203    0.825203
# macro avg      0.500000  0.412602  0.452116  246.000000
# weighted avg   1.000000  0.825203  0.904232  246.000000

# %%
lstmcnn = lstm_cnn()
preds = return_report(lstmcnn,50)
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 30)]              0
#
#  embedding_4 (Embedding)     (None, 30, 200)           378800
#
#  conv1d (Conv1D)             (None, 30, 32)            19232
#
#  max_pooling1d (MaxPooling1  (None, 15, 32)            0
#  D)
#
#  lstm_4 (LSTM)               (None, 100)               53200
#
#  dense_12 (Dense)            (None, 2)                 202
#
# =================================================================
# Total params: 451434 (1.72 MB)
# Trainable params: 72634 (283.73 KB)
# Non-trainable params: 378800 (1.45 MB)
# _________________________________________________________________
# None
# Epoch 1/50
# 58/58 [==============================] - 4s 11ms/step - loss: 0.6373 - accuracy: 0.6330
# Epoch 2/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.4901 - accuracy: 0.7856
# Epoch 3/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.4260 - accuracy: 0.8290
# Epoch 4/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.3851 - accuracy: 0.8485
# Epoch 5/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.3454 - accuracy: 0.8757
# Epoch 6/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.3129 - accuracy: 0.8871
# Epoch 7/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.2812 - accuracy: 0.9012
# Epoch 8/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.2594 - accuracy: 0.9142
# Epoch 9/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.2394 - accuracy: 0.9240
# Epoch 10/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.2389 - accuracy: 0.9153
# Epoch 11/50
# 58/58 [==============================] - 1s 10ms/step - loss: 0.2171 - accuracy: 0.9229
# Epoch 12/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1736 - accuracy: 0.9501
# Epoch 13/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1729 - accuracy: 0.9425
# Epoch 14/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1818 - accuracy: 0.9376
# Epoch 15/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1630 - accuracy: 0.9468
# Epoch 16/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1353 - accuracy: 0.9582
# Epoch 17/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1256 - accuracy: 0.9625
# Epoch 18/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1182 - accuracy: 0.9663
# Epoch 19/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1144 - accuracy: 0.9669
# Epoch 20/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1111 - accuracy: 0.9658
# Epoch 21/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1054 - accuracy: 0.9669
# Epoch 22/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.1103 - accuracy: 0.9696
# Epoch 23/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0931 - accuracy: 0.9696
# Epoch 24/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0956 - accuracy: 0.9707
# Epoch 25/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0836 - accuracy: 0.9756
# Epoch 26/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0878 - accuracy: 0.9745
# Epoch 27/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0838 - accuracy: 0.9788
# Epoch 28/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0783 - accuracy: 0.9750
# Epoch 29/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0665 - accuracy: 0.9821
# Epoch 30/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0651 - accuracy: 0.9821
# Epoch 31/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0732 - accuracy: 0.9788
# Epoch 32/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0766 - accuracy: 0.9783
# Epoch 33/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0612 - accuracy: 0.9810
# Epoch 34/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0508 - accuracy: 0.9848
# Epoch 35/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0667 - accuracy: 0.9815
# Epoch 36/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0587 - accuracy: 0.9843
# Epoch 37/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0461 - accuracy: 0.9897
# Epoch 38/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0542 - accuracy: 0.9864
# Epoch 39/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0561 - accuracy: 0.9826
# Epoch 40/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0603 - accuracy: 0.9832
# Epoch 41/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0516 - accuracy: 0.9837
# Epoch 42/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0759 - accuracy: 0.9783
# Epoch 43/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0470 - accuracy: 0.9886
# Epoch 44/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0464 - accuracy: 0.9881
# Epoch 45/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0412 - accuracy: 0.9891
# Epoch 46/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0454 - accuracy: 0.9886
# Epoch 47/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0327 - accuracy: 0.9902
# Epoch 48/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0387 - accuracy: 0.9908
# Epoch 49/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0366 - accuracy: 0.9891
# Epoch 50/50
# 58/58 [==============================] - 1s 11ms/step - loss: 0.0360 - accuracy: 0.9919
# 15/15 [==============================] - 0s 3ms/step
#               precision    recall  f1-score     support
# 0              0.825871  0.772093  0.798077  215.000000
# 1              0.811538  0.857724  0.833992  246.000000
# accuracy       0.817787  0.817787  0.817787    0.817787
# macro avg      0.818705  0.814908  0.816035  461.000000
# weighted avg   0.818223  0.817787  0.817242  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.772093  0.871391  215.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.772093  0.772093  0.772093    0.772093
# macro avg      0.500000  0.386047  0.435696  215.000000
# weighted avg   1.000000  0.772093  0.871391  215.000000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.000000  0.000000  0.000000    0.000000
# 1              1.000000  0.857724  0.923414  246.000000
# accuracy       0.857724  0.857724  0.857724    0.857724
# macro avg      0.500000  0.428862  0.461707  246.000000
# weighted avg   1.000000  0.857724  0.923414  246.000000

# %%
bilistm.save('task2_models/bi-lstm/model')
# Out:
# INFO:tensorflow:Assets written to: task2_models/bi-lstm/model\assets
# INFO:tensorflow:Assets written to: task2_models/bi-lstm/model\assets

# %% [markdown]
# ### Simple Classifiers

# %%
tag2idx = {t: i for i, t in enumerate(tags)}
max_len = 30
emb_dim = len(vec_model['the'])
X = []
y = []

for sent in sentences:
    vec = np.zeros((30,emb_dim))
    for i, word in enumerate(sent):
        if word in vec_model:
            vec[i,:] = vec_model[word]
    X.append(vec)
X = np.array(X)
y = np.array([tag2idx[tg] for tg in labels])
y = [[y[i],typs[i]] for i in range(len(y))]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
y_train = np.array([lab[0] for lab in y_train])
typ_test = [lab[1] for lab in y_test]
y_test = np.array([lab[0] for lab  in y_test])
X_train = X_train.reshape((X_train.shape[0],max_len*emb_dim))
X_test = X_test.reshape((X_test.shape[0],max_len*emb_dim))

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel='poly')
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
full_results(y_test,pred)

# %%
from sklearn.tree import DecisionTreeClassifier
