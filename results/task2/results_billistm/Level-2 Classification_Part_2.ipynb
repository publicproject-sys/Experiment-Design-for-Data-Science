# %% [markdown]
# ### Models Included
# - SVM
# - Bi-LSTM
# - BiLSTM with Attention
# - LSTM CNN

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, SimpleRNN, Flatten,\
Activation, RepeatVector, Permute, Concatenate, Lambda
#from tensorflow_addons.layers import CRF  # Assuming you're using TensorFlow Addons for CRF
from tensorflow.keras import optimizers
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import random
import subprocess
from sklearn.utils import class_weight
import tensorflow.keras.backend as K
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Multiply
from tensorflow.keras.layers import Conv1D, MaxPooling1D
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Move two levels up
grandparent_directory = os.path.abspath(os.path.join(current_directory, "..", "..", ".."))

# Specify the folder name
folder_name = "data"

# Combine the grandparent directory with the folder name
folder_path = os.path.join(grandparent_directory, folder_name)

# List files in the specified folder
files = os.listdir(folder_path)

# Select the "Task2.csv" file
task2_file = "Task2.csv"

if task2_file in files:
    print(f"The '{task2_file}' file is present in the '{folder_name}' folder.")
else:
    print(f"The '{task2_file}' file is not found in the '{folder_name}' folder.")

file_path=os.path.join(folder_path,task2_file)

print(f"The file path is {file_path}")
# Out:
# The 'Task2.csv' file is present in the 'data' folder.
# The file path is c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\data\Task2.csv

# %%
data = pd.read_csv(file_path)
data = data.rename(columns={'id':'Sentence #'})
data = data.dropna(axis=0)
#data = data.drop('Unnamed: 0',axis=1)

# %%
data.groupby('type').count()
# Out:
#       sentence_id  sentence  category
# type
# E            1129      1129      1129
# I            1174      1174      1174

# %%
data
# Out:
#       sentence_id                                           sentence  \
# 0               0  late afternoon a very hot day which took some ...
# 1               1                        concessions were overpriced
# 2               2                                queues were minimal
# 3               3                of truly healthy options for dining
# 4               4                       park entry fee is reasonable
# ...           ...                                                ...
# 2298         2151                                        in the rain
# 2299         2152                             without feeling pushed
# 2300         2152                                     claustrophobic
# 2301         2152                                   hordes of crowds
# 2302         2153                                         our family
#
#             category type
# 0     time/day/month    E
# 1              price    E
# 2             queues    I
# 3               food    E
# 4              price    I
# ...              ...  ...
# 2298  time/day/month    E
# 2299           crowd    I
# 2300  claustrophobic    E
# 2301           crowd    E
# 2302  couples/family    I
#
# [2303 rows x 4 columns]

# %%
sentences = []
labels = list(data['type']) 
typs = data['type'].values #Spelling error, there was it was types not type
x = data.apply(lambda l: sentences.append(l['sentence'].split(' ')),axis=1)

# %%
words = []
for sent in sentences:
    for wrd in sent:
        words.append(wrd)
words = list(set(words))
tags = list(set(labels))

n_words = len(words)
n_tags = len(tags)

# %%
len(typs)
# Out:
# 2303

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
max_len = 30
X = [[word2idx[w] for w in s] for s in sentences]    
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=0)
y = [tag2idx[tg] for tg in labels]
# y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])
y = np.array([to_categorical(i, num_classes=n_tags) for i in y])
y = [[y[i],typs[i]] for i in range(len(y))]
random.seed(2222222)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

y_train = np.array([lab[0] for lab in y_train])
typ_test = [lab[1] for lab in y_test]
y_test = np.array([lab[0] for lab  in y_test])

# %%
# def loadGloveModel(File):
#     print("Loading Glove Model")
#     f = open(File,'r')
#     gloveModel = {}
#     for line in f:
#         splitLines = line.split()
#         word = splitLines[0]
#         wordEmbedding = np.array([float(value) for value in splitLines[1:]])
#         gloveModel[word] = wordEmbedding
#     print(len(gloveModel)," words loaded!")
#     return gloveModel

# vec_model = loadGloveModel('glove/glove.6B.200d.txt')

# %%
def loadGloveModel(File):
    with open(File, 'r', encoding='utf-8') as f:
        gloveModel = {}
        for line in f:
            splitLines = line.split()
            word = splitLines[0]
            wordEmbedding = np.array([float(val) for val in splitLines[1:]])
            gloveModel[word] = wordEmbedding
    print(len(gloveModel), "words loaded!")
    return gloveModel

vec_model = loadGloveModel('glove/glove.6B.200d.txt')
# Out:
# 400000 words loaded!

# %%
emb_dim = len(vec_model['the'])
embedding_matrix = np.zeros((len(word2idx) + 1, emb_dim))

for word, i in word2idx.items():
    if word not in vec_model:
        continue
    embedding_vector = vec_model[word]
    embedding_matrix[i] = embedding_vector

print(embedding_matrix.shape)
# Out:
# (1894, 200)

# %%
def full_results(y_test,pred):
    
    report = classification_report(y_test,pred.flatten('F'),output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    
    inc_test = []
    exc_test = []
    inc_pred = []
    exc_pred = []
    for i,t in enumerate(typ_test):
        if t == 'I':
            inc_test.append(y_test[i])
            inc_pred.append(pred[i])
        else:
            exc_test.append(y_test[i])
            exc_pred.append(pred[i])
    print("For inclusions")
    report = classification_report(inc_test,inc_pred,output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    print("For exclusions")
    report = classification_report(exc_test,exc_pred,output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    return

def return_report(model,epochs):
    y_flat = list(np.argmax(y_test,1).flatten('F'))
#     class_weights = class_weight.compute_class_weight('balanced',y_flat)
#     class_weights = [1,10,20,10,20]
    model.fit(X_train,y_train,epochs=epochs,verbose=1)
    out = model.predict(X_test)
    pred = np.argmax(out,1)
    full_results(y_flat,pred)
    return pred

# %%
def get_bilstm_lstm_model():
    
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)

    # Add bidirectional LSTM
    model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)    
    
    model = TimeDistributed(Dense(100,activation='relu'))(model)
    model = Flatten()(model)
    model = Dense(100,activation='relu')(model)
    # Add timeDistributed Layer
    out = Dense(n_tags, activation="softmax")(model)

    #Optimiser 
    adam = Adam(lr=0.0007)

    # Compile model
    model = Model(input, out)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    
    return model

def lstm_attention():
    
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)

    # Add bidirectional LSTM
    model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)

    attention = TimeDistributed(Dense(1, activation='tanh'))(model) 
    attention = Flatten()(attention)
    attention = Activation('softmax')(attention)
    attention = RepeatVector(2*emb_dim)(attention)
    attention = Permute([2, 1])(attention)

    # apply the attention
    sent_representation = Multiply()([model, attention])
    sent_representation = Lambda(lambda xin: K.sum(xin, axis=1))(sent_representation)
    probabilities = Dense(3, activation='softmax')(sent_representation)
    
    # Add timeDistributed Layer
    out = Dense(n_tags, activation="softmax")(sent_representation)

    #Optimiser 
    adam = Adam(lr=0.0007)

    # Compile model
    model = Model(input, out)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    
    return model

def lstm_cnn():
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)
    model = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu')(model)
    model = MaxPooling1D(pool_size=2)(model)
    model = LSTM(100,dropout=0.2,recurrent_dropout=0.2)(model)
    out = Dense(n_tags, activation='softmax')(model)
    model = Model(input,out)
    adam = Adam(lr=0.0007)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    print(model.summary())
    
    return model

# %%
# from keras.layers import InputLayer

# def get_bilstm_lstm_model():
    
#     input_layer = Input(shape=(max_len,))

#     # Add Embedding layer
#     model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
#                   input_length=max_len, weights=[embedding_matrix], trainable=False)(input_layer)

#     # Add bidirectional LSTM
#     model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)    
    
#     model = TimeDistributed(Dense(100, activation='relu'))(model)
#     model = Flatten()(model)
#     model = Dense(100, activation='relu')(model)
#     # Add timeDistributed Layer
#     out = Dense(n_tags, activation="softmax")(model)

#     # Optimizer 
#     adam = ko.Adam(lr=0.0007)

#     # Compile model
#     model = Model(input_layer, out)
#     model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#     model.summary()
    
#     return model

# %%
bilistm = get_bilstm_lstm_model()
pred = return_report(bilistm,25)
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30)]              0
#
#  embedding (Embedding)       (None, 30, 200)           378800
#
#  bidirectional (Bidirection  (None, 30, 400)           641600
#  al)
#
#  time_distributed (TimeDist  (None, 30, 100)           40100
#  ributed)
#
#  flatten (Flatten)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 100)               300100
#
#  dense_2 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 1360802 (5.19 MB)
# Trainable params: 982002 (3.75 MB)
# Non-trainable params: 378800 (1.45 MB)
# _________________________________________________________________
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 58/58 [==============================] - 92s 232ms/step - loss: 0.5609 - accuracy: 0.7172
# Epoch 2/25
# 58/58 [==============================] - 13s 227ms/step - loss: 0.4500 - accuracy: 0.7894
# Epoch 3/25
# 58/58 [==============================] - 13s 220ms/step - loss: 0.3864 - accuracy: 0.8295
# Epoch 4/25
# 58/58 [==============================] - 13s 217ms/step - loss: 0.3188 - accuracy: 0.8730
# Epoch 5/25
# 58/58 [==============================] - 12s 213ms/step - loss: 0.2620 - accuracy: 0.8893
# Epoch 6/25
# 58/58 [==============================] - 14s 238ms/step - loss: 0.2069 - accuracy: 0.9131
# Epoch 7/25
# 58/58 [==============================] - 14s 236ms/step - loss: 0.1550 - accuracy: 0.9430
# Epoch 8/25
# 58/58 [==============================] - 13s 217ms/step - loss: 0.1266 - accuracy: 0.9533
# Epoch 9/25
# 58/58 [==============================] - 13s 223ms/step - loss: 0.0931 - accuracy: 0.9658
# Epoch 10/25
# 58/58 [==============================] - 14s 238ms/step - loss: 0.0669 - accuracy: 0.9767
# Epoch 11/25
# 58/58 [==============================] - 14s 234ms/step - loss: 0.0632 - accuracy: 0.9761
# Epoch 12/25
# 58/58 [==============================] - 13s 217ms/step - loss: 0.0584 - accuracy: 0.9772
# Epoch 13/25
# 58/58 [==============================] - 9s 162ms/step - loss: 0.0494 - accuracy: 0.9837
# Epoch 14/25
# 58/58 [==============================] - 7s 123ms/step - loss: 0.0299 - accuracy: 0.9902
# Epoch 15/25
# 58/58 [==============================] - 7s 119ms/step - loss: 0.0322 - accuracy: 0.9881
# Epoch 16/25
# 58/58 [==============================] - 7s 117ms/step - loss: 0.0497 - accuracy: 0.9853
# Epoch 17/25
# 58/58 [==============================] - 7s 121ms/step - loss: 0.0208 - accuracy: 0.9935
# Epoch 18/25
# 58/58 [==============================] - 8s 131ms/step - loss: 0.0304 - accuracy: 0.9891
# Epoch 19/25
# 58/58 [==============================] - 8s 134ms/step - loss: 0.0422 - accuracy: 0.9875
# Epoch 20/25
# 58/58 [==============================] - 7s 122ms/step - loss: 0.0178 - accuracy: 0.9946
# Epoch 21/25
# 58/58 [==============================] - 7s 128ms/step - loss: 0.0088 - accuracy: 0.9978
# Epoch 22/25
# 58/58 [==============================] - 8s 142ms/step - loss: 0.0163 - accuracy: 0.9924
# Epoch 23/25
# 58/58 [==============================] - 8s 138ms/step - loss: 0.0433 - accuracy: 0.9843
# Epoch 24/25
# 58/58 [==============================] - 9s 147ms/step - loss: 0.0546 - accuracy: 0.9799
# Epoch 25/25
# 58/58 [==============================] - 9s 151ms/step - loss: 0.0260 - accuracy: 0.9919
# 15/15 [==============================] - 2s 30ms/step
#               precision    recall  f1-score     support
# 0              0.786026  0.853081  0.818182  211.000000
# 1              0.866379  0.804000  0.834025  250.000000
# accuracy       0.826464  0.826464  0.826464    0.826464
# macro avg      0.826203  0.828540  0.826103  461.000000
# weighted avg   0.829602  0.826464  0.826774  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score  support
# 0                 0.000   0.000  0.000000    0.000
# 1                 1.000   0.804  0.891353  250.000
# accuracy          0.804   0.804  0.804000    0.804
# macro avg         0.500   0.402  0.445676  250.000
# weighted avg      1.000   0.804  0.891353  250.000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.853081  0.920716  211.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.853081  0.853081  0.853081    0.853081
# macro avg      0.500000  0.426540  0.460358  211.000000
# weighted avg   1.000000  0.853081  0.920716  211.000000

# %%
attn = lstm_attention()
preds = return_report(attn,50)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 200)              378800    ['input_2[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 30, 400)              641600    ['embedding_1[0][0]']
#  onal)
#
#  time_distributed_1 (TimeDi  (None, 30, 1)                401       ['bidirectional_1[0][0]']
#  stributed)
#
#  flatten_1 (Flatten)         (None, 30)                   0         ['time_distributed_1[0][0]']
#
#  activation (Activation)     (None, 30)                   0         ['flatten_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 400, 30)              0         ['activation[0][0]']
#  r)
#
#  permute (Permute)           (None, 30, 400)              0         ['repeat_vector[0][0]']
#
#  multiply (Multiply)         (None, 30, 400)              0         ['bidirectional_1[0][0]',
#                                                                      'permute[0][0]']
#
#  lambda (Lambda)             (None, 400)                  0         ['multiply[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    802       ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1021603 (3.90 MB)
# Trainable params: 642803 (2.45 MB)
# Non-trainable params: 378800 (1.45 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 58/58 [==============================] - 25s 143ms/step - loss: 0.5887 - accuracy: 0.6960
# Epoch 2/50
# 58/58 [==============================] - 8s 141ms/step - loss: 0.4909 - accuracy: 0.7796
# Epoch 3/50
# 58/58 [==============================] - 8s 133ms/step - loss: 0.4506 - accuracy: 0.8046
# Epoch 4/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.4148 - accuracy: 0.8127
# Epoch 5/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.3826 - accuracy: 0.8301
# Epoch 6/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.3689 - accuracy: 0.8366
# Epoch 7/50
# 58/58 [==============================] - 7s 123ms/step - loss: 0.3425 - accuracy: 0.8545
# Epoch 8/50
# 58/58 [==============================] - 6s 112ms/step - loss: 0.3369 - accuracy: 0.8464
# Epoch 9/50
# 58/58 [==============================] - 7s 120ms/step - loss: 0.2773 - accuracy: 0.8844
# Epoch 10/50
# 58/58 [==============================] - 7s 122ms/step - loss: 0.2832 - accuracy: 0.8795
# Epoch 11/50
# 58/58 [==============================] - 7s 121ms/step - loss: 0.2346 - accuracy: 0.9099
# Epoch 12/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.1882 - accuracy: 0.9240
# Epoch 13/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.1840 - accuracy: 0.9300
# Epoch 14/50
# 58/58 [==============================] - 7s 120ms/step - loss: 0.1655 - accuracy: 0.9365
# Epoch 15/50
# 58/58 [==============================] - 7s 119ms/step - loss: 0.1562 - accuracy: 0.9354
# Epoch 16/50
# 58/58 [==============================] - 7s 121ms/step - loss: 0.1263 - accuracy: 0.9533
# Epoch 17/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.1275 - accuracy: 0.9539
# Epoch 18/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.1140 - accuracy: 0.9571
# Epoch 19/50
# 58/58 [==============================] - 6s 110ms/step - loss: 0.1020 - accuracy: 0.9625
# Epoch 20/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.1122 - accuracy: 0.9598
# Epoch 21/50
# 58/58 [==============================] - 7s 122ms/step - loss: 0.1000 - accuracy: 0.9609
# Epoch 22/50
# 58/58 [==============================] - 7s 127ms/step - loss: 0.0739 - accuracy: 0.9739
# Epoch 23/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0630 - accuracy: 0.9805
# Epoch 24/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0599 - accuracy: 0.9783
# Epoch 25/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.0687 - accuracy: 0.9750
# Epoch 26/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.0468 - accuracy: 0.9821
# Epoch 27/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0460 - accuracy: 0.9843
# Epoch 28/50
# 58/58 [==============================] - 6s 108ms/step - loss: 0.0561 - accuracy: 0.9810
# Epoch 29/50
# 58/58 [==============================] - 6s 111ms/step - loss: 0.0531 - accuracy: 0.9815
# Epoch 30/50
# 58/58 [==============================] - 6s 110ms/step - loss: 0.0452 - accuracy: 0.9864
# Epoch 31/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0435 - accuracy: 0.9870
# Epoch 32/50
# 58/58 [==============================] - 7s 124ms/step - loss: 0.0260 - accuracy: 0.9929
# Epoch 33/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.0270 - accuracy: 0.9902
# Epoch 34/50
# 58/58 [==============================] - 6s 112ms/step - loss: 0.0212 - accuracy: 0.9929
# Epoch 35/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0309 - accuracy: 0.9897
# Epoch 36/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0281 - accuracy: 0.9908
# Epoch 37/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0194 - accuracy: 0.9929
# Epoch 38/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0207 - accuracy: 0.9940
# Epoch 39/50
# 58/58 [==============================] - 7s 113ms/step - loss: 0.0192 - accuracy: 0.9946
# Epoch 40/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0223 - accuracy: 0.9919
# Epoch 41/50
# 58/58 [==============================] - 7s 120ms/step - loss: 0.0196 - accuracy: 0.9940
# Epoch 42/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0122 - accuracy: 0.9973
# Epoch 43/50
# 58/58 [==============================] - 7s 115ms/step - loss: 0.0180 - accuracy: 0.9957
# Epoch 44/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0174 - accuracy: 0.9924
# Epoch 45/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0323 - accuracy: 0.9913
# Epoch 46/50
# 58/58 [==============================] - 7s 121ms/step - loss: 0.0339 - accuracy: 0.9875
# Epoch 47/50
# 58/58 [==============================] - 7s 121ms/step - loss: 0.0178 - accuracy: 0.9940
# Epoch 48/50
# 58/58 [==============================] - 7s 118ms/step - loss: 0.0176 - accuracy: 0.9951
# Epoch 49/50
# 58/58 [==============================] - 7s 117ms/step - loss: 0.0105 - accuracy: 0.9978
# Epoch 50/50
# 58/58 [==============================] - 7s 116ms/step - loss: 0.0077 - accuracy: 0.9995
# 15/15 [==============================] - 1s 22ms/step
#               precision    recall  f1-score     support
# 0              0.780269  0.824645  0.801843  211.000000
# 1              0.844538  0.804000  0.823770  250.000000
# accuracy       0.813449  0.813449  0.813449    0.813449
# macro avg      0.812403  0.814322  0.812807  461.000000
# weighted avg   0.815122  0.813449  0.813734  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score  support
# 0                 0.000   0.000  0.000000    0.000
# 1                 1.000   0.804  0.891353  250.000
# accuracy          0.804   0.804  0.804000    0.804
# macro avg         0.500   0.402  0.445676  250.000
# weighted avg      1.000   0.804  0.891353  250.000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.824645  0.903896  211.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.824645  0.824645  0.824645    0.824645
# macro avg      0.500000  0.412322  0.451948  211.000000
# weighted avg   1.000000  0.824645  0.903896  211.000000

# %%
lstmcnn = lstm_cnn()
preds = return_report(lstmcnn,50)
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 30)]              0
#
#  embedding_2 (Embedding)     (None, 30, 200)           378800
#
#  conv1d (Conv1D)             (None, 30, 32)            19232
#
#  max_pooling1d (MaxPooling1  (None, 15, 32)            0
#  D)
#
#  lstm_2 (LSTM)               (None, 100)               53200
#
#  dense_6 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 451434 (1.72 MB)
# Trainable params: 72634 (283.73 KB)
# Non-trainable params: 378800 (1.45 MB)
# _________________________________________________________________
# None
# Epoch 1/50
# 58/58 [==============================] - 4s 12ms/step - loss: 0.5998 - accuracy: 0.6835
# Epoch 2/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.4815 - accuracy: 0.7818
# Epoch 3/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.4299 - accuracy: 0.8198
# Epoch 4/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.3771 - accuracy: 0.8507
# Epoch 5/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.3305 - accuracy: 0.8768
# Epoch 6/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.3157 - accuracy: 0.8876
# Epoch 7/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.2854 - accuracy: 0.9023
# Epoch 8/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.2648 - accuracy: 0.9083
# Epoch 9/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.2432 - accuracy: 0.9191
# Epoch 10/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.2212 - accuracy: 0.9294
# Epoch 11/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.2177 - accuracy: 0.9311
# Epoch 12/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.2052 - accuracy: 0.9300
# Epoch 13/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1970 - accuracy: 0.9349
# Epoch 14/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1956 - accuracy: 0.9376
# Epoch 15/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1571 - accuracy: 0.9473
# Epoch 16/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1433 - accuracy: 0.9539
# Epoch 17/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1332 - accuracy: 0.9593
# Epoch 18/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1398 - accuracy: 0.9528
# Epoch 19/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1316 - accuracy: 0.9598
# Epoch 20/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1144 - accuracy: 0.9642
# Epoch 21/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1131 - accuracy: 0.9620
# Epoch 22/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.1133 - accuracy: 0.9615
# Epoch 23/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0932 - accuracy: 0.9685
# Epoch 24/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0933 - accuracy: 0.9685
# Epoch 25/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0913 - accuracy: 0.9734
# Epoch 26/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0703 - accuracy: 0.9750
# Epoch 27/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0655 - accuracy: 0.9783
# Epoch 28/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0765 - accuracy: 0.9761
# Epoch 29/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0590 - accuracy: 0.9837
# Epoch 30/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0585 - accuracy: 0.9826
# Epoch 31/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0616 - accuracy: 0.9826
# Epoch 32/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0620 - accuracy: 0.9805
# Epoch 33/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0580 - accuracy: 0.9821
# Epoch 34/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0474 - accuracy: 0.9859
# Epoch 35/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0527 - accuracy: 0.9799
# Epoch 36/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0469 - accuracy: 0.9864
# Epoch 37/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0490 - accuracy: 0.9859
# Epoch 38/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0304 - accuracy: 0.9924
# Epoch 39/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0576 - accuracy: 0.9837
# Epoch 40/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0386 - accuracy: 0.9886
# Epoch 41/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0457 - accuracy: 0.9864
# Epoch 42/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0253 - accuracy: 0.9913
# Epoch 43/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0293 - accuracy: 0.9897
# Epoch 44/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0327 - accuracy: 0.9919
# Epoch 45/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0358 - accuracy: 0.9891
# Epoch 46/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0242 - accuracy: 0.9897
# Epoch 47/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0327 - accuracy: 0.9902
# Epoch 48/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0394 - accuracy: 0.9875
# Epoch 49/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0367 - accuracy: 0.9902
# Epoch 50/50
# 58/58 [==============================] - 1s 12ms/step - loss: 0.0257 - accuracy: 0.9940
# 15/15 [==============================] - 0s 4ms/step
#               precision    recall  f1-score     support
# 0              0.727273  0.834123  0.777042  211.000000
# 1              0.840183  0.736000  0.784648  250.000000
# accuracy       0.780911  0.780911  0.780911    0.780911
# macro avg      0.783728  0.785062  0.780845  461.000000
# weighted avg   0.788504  0.780911  0.781167  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision  recall  f1-score  support
# 0                 0.000   0.000  0.000000    0.000
# 1                 1.000   0.736  0.847926  250.000
# accuracy          0.736   0.736  0.736000    0.736
# macro avg         0.500   0.368  0.423963  250.000
# weighted avg      1.000   0.736  0.847926  250.000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.834123  0.909561  211.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.834123  0.834123  0.834123    0.834123
# macro avg      0.500000  0.417062  0.454780  211.000000
# weighted avg   1.000000  0.834123  0.909561  211.000000

# %%
bilistm.save('task2_models/bi-lstm/model')
# Out:
# INFO:tensorflow:Assets written to: task2_models/bi-lstm/model\assets
# INFO:tensorflow:Assets written to: task2_models/bi-lstm/model\assets

# %% [markdown]
# ### Simple Classifiers

# %%
tag2idx = {t: i for i, t in enumerate(tags)}
max_len = 30
emb_dim = len(vec_model['the'])
X = []
y = []

for sent in sentences:
    vec = np.zeros((30,emb_dim))
    for i, word in enumerate(sent):
        if word in vec_model:
            vec[i,:] = vec_model[word]
    X.append(vec)
X = np.array(X)
y = np.array([tag2idx[tg] for tg in labels])
y = [[y[i],typs[i]] for i in range(len(y))]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
y_train = np.array([lab[0] for lab in y_train])
typ_test = [lab[1] for lab in y_test]
y_test = np.array([lab[0] for lab  in y_test])
X_train = X_train.reshape((X_train.shape[0],max_len*emb_dim))
X_test = X_test.reshape((X_test.shape[0],max_len*emb_dim))

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel='poly')
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
full_results(y_test,pred)

# %%
from sklearn.tree import DecisionTreeClassifier
