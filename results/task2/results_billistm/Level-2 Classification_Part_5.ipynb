# %% [markdown]
# ### Models Included
# - SVM
# - Bi-LSTM
# - BiLSTM with Attention
# - LSTM CNN

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, SimpleRNN, Flatten,\
Activation, RepeatVector, Permute, Concatenate, Lambda
#from tensorflow_addons.layers import CRF  # Assuming you're using TensorFlow Addons for CRF
from tensorflow.keras import optimizers
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
import random
import subprocess
from sklearn.utils import class_weight
import tensorflow.keras.backend as K
from tensorflow.keras import Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Multiply
from tensorflow.keras.layers import Conv1D, MaxPooling1D
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

# Move two levels up
grandparent_directory = os.path.abspath(os.path.join(current_directory, "..", "..", ".."))

# Specify the folder name
folder_name = "data"

# Combine the grandparent directory with the folder name
folder_path = os.path.join(grandparent_directory, folder_name)

# List files in the specified folder
files = os.listdir(folder_path)

# Select the "Task2.csv" file
task2_file = "Task2.csv"

if task2_file in files:
    print(f"The '{task2_file}' file is present in the '{folder_name}' folder.")
else:
    print(f"The '{task2_file}' file is not found in the '{folder_name}' folder.")

file_path=os.path.join(folder_path,task2_file)

print(f"The file path is {file_path}")
# Out:
# The 'Task2.csv' file is present in the 'data' folder.
# The file path is c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\data\Task2.csv

# %%
data = pd.read_csv(file_path)
data = data.rename(columns={'id':'Sentence #'})
data = data.dropna(axis=0)
#data = data.drop('Unnamed: 0',axis=1)

# %%
data.groupby('type').count()
# Out:
#       sentence_id  sentence  category
# type
# E            1129      1129      1129
# I            1174      1174      1174

# %%
data
# Out:
#       sentence_id                                           sentence  \
# 0               0  late afternoon a very hot day which took some ...
# 1               1                        concessions were overpriced
# 2               2                                queues were minimal
# 3               3                of truly healthy options for dining
# 4               4                       park entry fee is reasonable
# ...           ...                                                ...
# 2298         2151                                        in the rain
# 2299         2152                             without feeling pushed
# 2300         2152                                     claustrophobic
# 2301         2152                                   hordes of crowds
# 2302         2153                                         our family
#
#             category type
# 0     time/day/month    E
# 1              price    E
# 2             queues    I
# 3               food    E
# 4              price    I
# ...              ...  ...
# 2298  time/day/month    E
# 2299           crowd    I
# 2300  claustrophobic    E
# 2301           crowd    E
# 2302  couples/family    I
#
# [2303 rows x 4 columns]

# %%
sentences = []
labels = list(data['type']) 
typs = data['type'].values #Spelling error, there was it was types not type
x = data.apply(lambda l: sentences.append(l['sentence'].split(' ')),axis=1)

# %%
words = []
for sent in sentences:
    for wrd in sent:
        words.append(wrd)
words = list(set(words))
tags = list(set(labels))

n_words = len(words)
n_tags = len(tags)

# %%
len(typs)
# Out:
# 2303

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}
max_len = 30
X = [[word2idx[w] for w in s] for s in sentences]    
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=0)
y = [tag2idx[tg] for tg in labels]
# y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])
y = np.array([to_categorical(i, num_classes=n_tags) for i in y])
y = [[y[i],typs[i]] for i in range(len(y))]
random.seed(55555555)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

y_train = np.array([lab[0] for lab in y_train])
typ_test = [lab[1] for lab in y_test]
y_test = np.array([lab[0] for lab  in y_test])

# %%
# def loadGloveModel(File):
#     print("Loading Glove Model")
#     f = open(File,'r')
#     gloveModel = {}
#     for line in f:
#         splitLines = line.split()
#         word = splitLines[0]
#         wordEmbedding = np.array([float(value) for value in splitLines[1:]])
#         gloveModel[word] = wordEmbedding
#     print(len(gloveModel)," words loaded!")
#     return gloveModel

# vec_model = loadGloveModel('glove/glove.6B.200d.txt')

# %%
def loadGloveModel(File):
    with open(File, 'r', encoding='utf-8') as f:
        gloveModel = {}
        for line in f:
            splitLines = line.split()
            word = splitLines[0]
            wordEmbedding = np.array([float(val) for val in splitLines[1:]])
            gloveModel[word] = wordEmbedding
    print(len(gloveModel), "words loaded!")
    return gloveModel

vec_model = loadGloveModel('glove/glove.6B.200d.txt')
# Out:
# 400000 words loaded!

# %%
emb_dim = len(vec_model['the'])
embedding_matrix = np.zeros((len(word2idx) + 1, emb_dim))

for word, i in word2idx.items():
    if word not in vec_model:
        continue
    embedding_vector = vec_model[word]
    embedding_matrix[i] = embedding_vector

print(embedding_matrix.shape)
# Out:
# (1894, 200)

# %%
def full_results(y_test,pred):
    
    report = classification_report(y_test,pred.flatten('F'),output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    
    inc_test = []
    exc_test = []
    inc_pred = []
    exc_pred = []
    for i,t in enumerate(typ_test):
        if t == 'I':
            inc_test.append(y_test[i])
            inc_pred.append(pred[i])
        else:
            exc_test.append(y_test[i])
            exc_pred.append(pred[i])
    print("For inclusions")
    report = classification_report(inc_test,inc_pred,output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    print("For exclusions")
    report = classification_report(exc_test,exc_pred,output_dict=True)
    df = pd.DataFrame(report).transpose()
    display(df)
    return

def return_report(model,epochs):
    y_flat = list(np.argmax(y_test,1).flatten('F'))
#     class_weights = class_weight.compute_class_weight('balanced',y_flat)
#     class_weights = [1,10,20,10,20]
    model.fit(X_train,y_train,epochs=epochs,verbose=1)
    out = model.predict(X_test)
    pred = np.argmax(out,1)
    full_results(y_flat,pred)
    return pred

# %%
def get_bilstm_lstm_model():
    
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)

    # Add bidirectional LSTM
    model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)    
    
    model = TimeDistributed(Dense(100,activation='relu'))(model)
    model = Flatten()(model)
    model = Dense(100,activation='relu')(model)
    # Add timeDistributed Layer
    out = Dense(n_tags, activation="softmax")(model)

    #Optimiser 
    adam = Adam(lr=0.0007)

    # Compile model
    model = Model(input, out)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    
    return model

def lstm_attention():
    
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)

    # Add bidirectional LSTM
    model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)

    attention = TimeDistributed(Dense(1, activation='tanh'))(model) 
    attention = Flatten()(attention)
    attention = Activation('softmax')(attention)
    attention = RepeatVector(2*emb_dim)(attention)
    attention = Permute([2, 1])(attention)

    # apply the attention
    sent_representation = Multiply()([model, attention])
    sent_representation = Lambda(lambda xin: K.sum(xin, axis=1))(sent_representation)
    probabilities = Dense(3, activation='softmax')(sent_representation)
    
    # Add timeDistributed Layer
    out = Dense(n_tags, activation="softmax")(sent_representation)

    #Optimiser 
    adam = Adam(lr=0.0007)

    # Compile model
    model = Model(input, out)
    model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
    model.summary()
    
    return model

def lstm_cnn():
    input = Input(shape=(max_len,))

    # Add Embedding layer
    model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
                  input_length=max_len, weights=[embedding_matrix],trainable=False)(input)
    model = Conv1D(filters=32, kernel_size=3, padding='same', activation='relu')(model)
    model = MaxPooling1D(pool_size=2)(model)
    model = LSTM(100,dropout=0.2,recurrent_dropout=0.2)(model)
    out = Dense(n_tags, activation='softmax')(model)
    model = Model(input,out)
    adam = Adam(lr=0.0007)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    print(model.summary())
    
    return model

# %%
# from keras.layers import InputLayer

# def get_bilstm_lstm_model():
    
#     input_layer = Input(shape=(max_len,))

#     # Add Embedding layer
#     model = Embedding(input_dim=n_words + 1, output_dim=emb_dim,
#                   input_length=max_len, weights=[embedding_matrix], trainable=False)(input_layer)

#     # Add bidirectional LSTM
#     model = Bidirectional(LSTM(units=emb_dim, return_sequences=True, dropout=0.2, recurrent_dropout=0.1))(model)    
    
#     model = TimeDistributed(Dense(100, activation='relu'))(model)
#     model = Flatten()(model)
#     model = Dense(100, activation='relu')(model)
#     # Add timeDistributed Layer
#     out = Dense(n_tags, activation="softmax")(model)

#     # Optimizer 
#     adam = ko.Adam(lr=0.0007)

#     # Compile model
#     model = Model(input_layer, out)
#     model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])
#     model.summary()
    
#     return model

# %%
bilistm = get_bilstm_lstm_model()
pred = return_report(bilistm,25)
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30)]              0
#
#  embedding (Embedding)       (None, 30, 200)           378800
#
#  bidirectional (Bidirection  (None, 30, 400)           641600
#  al)
#
#  time_distributed (TimeDist  (None, 30, 100)           40100
#  ributed)
#
#  flatten (Flatten)           (None, 3000)              0
#
#  dense_1 (Dense)             (None, 100)               300100
#
#  dense_2 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 1360802 (5.19 MB)
# Trainable params: 982002 (3.75 MB)
# Non-trainable params: 378800 (1.45 MB)
# _________________________________________________________________
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 58/58 [==============================] - 22s 254ms/step - loss: 0.5870 - accuracy: 0.6802
# Epoch 2/25
# 58/58 [==============================] - 13s 230ms/step - loss: 0.4437 - accuracy: 0.7986
# Epoch 3/25
# 58/58 [==============================] - 13s 227ms/step - loss: 0.3936 - accuracy: 0.8170
# Epoch 4/25
# 58/58 [==============================] - 13s 221ms/step - loss: 0.3241 - accuracy: 0.8588
# Epoch 5/25
# 58/58 [==============================] - 13s 219ms/step - loss: 0.2572 - accuracy: 0.8969
# Epoch 6/25
# 58/58 [==============================] - 13s 217ms/step - loss: 0.2039 - accuracy: 0.9191
# Epoch 7/25
# 58/58 [==============================] - 13s 225ms/step - loss: 0.1614 - accuracy: 0.9321
# Epoch 8/25
# 58/58 [==============================] - 13s 226ms/step - loss: 0.1126 - accuracy: 0.9571
# Epoch 9/25
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0897 - accuracy: 0.9642
# Epoch 10/25
# 58/58 [==============================] - 13s 222ms/step - loss: 0.0833 - accuracy: 0.9696
# Epoch 11/25
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0541 - accuracy: 0.9794
# Epoch 12/25
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0595 - accuracy: 0.9794
# Epoch 13/25
# 58/58 [==============================] - 13s 223ms/step - loss: 0.0485 - accuracy: 0.9864
# Epoch 14/25
# 58/58 [==============================] - 13s 223ms/step - loss: 0.0509 - accuracy: 0.9810
# Epoch 15/25
# 58/58 [==============================] - 13s 221ms/step - loss: 0.0320 - accuracy: 0.9891
# Epoch 16/25
# 58/58 [==============================] - 13s 226ms/step - loss: 0.0223 - accuracy: 0.9946
# Epoch 17/25
# 58/58 [==============================] - 13s 223ms/step - loss: 0.0242 - accuracy: 0.9908
# Epoch 18/25
# 58/58 [==============================] - 13s 226ms/step - loss: 0.0403 - accuracy: 0.9870
# Epoch 19/25
# 58/58 [==============================] - 13s 225ms/step - loss: 0.0220 - accuracy: 0.9919
# Epoch 20/25
# 58/58 [==============================] - 13s 220ms/step - loss: 0.0270 - accuracy: 0.9929
# Epoch 21/25
# 58/58 [==============================] - 13s 226ms/step - loss: 0.0549 - accuracy: 0.9815
# Epoch 22/25
# 58/58 [==============================] - 13s 219ms/step - loss: 0.0157 - accuracy: 0.9946
# Epoch 23/25
# 58/58 [==============================] - 13s 217ms/step - loss: 0.0245 - accuracy: 0.9924
# Epoch 24/25
# 58/58 [==============================] - 12s 213ms/step - loss: 0.0095 - accuracy: 0.9978
# Epoch 25/25
# 58/58 [==============================] - 11s 190ms/step - loss: 0.0040 - accuracy: 0.9995
# 15/15 [==============================] - 1s 23ms/step
#               precision    recall  f1-score     support
# 0              0.831897  0.889401  0.859688  217.000000
# 1              0.895197  0.840164  0.866808  244.000000
# accuracy       0.863341  0.863341  0.863341    0.863341
# macro avg      0.863547  0.864782  0.863248  461.000000
# weighted avg   0.865400  0.863341  0.863456  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.889401  0.941463  217.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.889401  0.889401  0.889401    0.889401
# macro avg      0.500000  0.444700  0.470732  217.000000
# weighted avg   1.000000  0.889401  0.941463  217.000000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.000000  0.000000  0.000000    0.000000
# 1              1.000000  0.840164  0.913140  244.000000
# accuracy       0.840164  0.840164  0.840164    0.840164
# macro avg      0.500000  0.420082  0.456570  244.000000
# weighted avg   1.000000  0.840164  0.913140  244.000000

# %%
attn = lstm_attention()
preds = return_report(attn,50)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 30)]                 0         []
#
#  embedding_1 (Embedding)     (None, 30, 200)              378800    ['input_2[0][0]']
#
#  bidirectional_1 (Bidirecti  (None, 30, 400)              641600    ['embedding_1[0][0]']
#  onal)
#
#  time_distributed_1 (TimeDi  (None, 30, 1)                401       ['bidirectional_1[0][0]']
#  stributed)
#
#  flatten_1 (Flatten)         (None, 30)                   0         ['time_distributed_1[0][0]']
#
#  activation (Activation)     (None, 30)                   0         ['flatten_1[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 400, 30)              0         ['activation[0][0]']
#  r)
#
#  permute (Permute)           (None, 30, 400)              0         ['repeat_vector[0][0]']
#
#  multiply (Multiply)         (None, 30, 400)              0         ['bidirectional_1[0][0]',
#                                                                      'permute[0][0]']
#
#  lambda (Lambda)             (None, 400)                  0         ['multiply[0][0]']
#
#  dense_5 (Dense)             (None, 2)                    802       ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 1021603 (3.90 MB)
# Trainable params: 642803 (2.45 MB)
# Non-trainable params: 378800 (1.45 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# 58/58 [==============================] - 21s 214ms/step - loss: 0.5778 - accuracy: 0.7003
# Epoch 2/50
# 58/58 [==============================] - 14s 236ms/step - loss: 0.4813 - accuracy: 0.7834
# Epoch 3/50
# 58/58 [==============================] - 13s 233ms/step - loss: 0.4601 - accuracy: 0.7899
# Epoch 4/50
# 58/58 [==============================] - 13s 227ms/step - loss: 0.4337 - accuracy: 0.8029
# Epoch 5/50
# 58/58 [==============================] - 13s 228ms/step - loss: 0.3790 - accuracy: 0.8274
# Epoch 6/50
# 58/58 [==============================] - 13s 230ms/step - loss: 0.3517 - accuracy: 0.8420
# Epoch 7/50
# 58/58 [==============================] - 13s 228ms/step - loss: 0.3180 - accuracy: 0.8583
# Epoch 8/50
# 58/58 [==============================] - 13s 225ms/step - loss: 0.3198 - accuracy: 0.8599
# Epoch 9/50
# 58/58 [==============================] - 14s 236ms/step - loss: 0.2954 - accuracy: 0.8730
# Epoch 10/50
# 58/58 [==============================] - 14s 236ms/step - loss: 0.2828 - accuracy: 0.8740
# Epoch 11/50
# 58/58 [==============================] - 13s 225ms/step - loss: 0.2427 - accuracy: 0.8947
# Epoch 12/50
# 58/58 [==============================] - 13s 227ms/step - loss: 0.2157 - accuracy: 0.9164
# Epoch 13/50
# 58/58 [==============================] - 13s 219ms/step - loss: 0.1904 - accuracy: 0.9256
# Epoch 14/50
# 58/58 [==============================] - 13s 221ms/step - loss: 0.1723 - accuracy: 0.9349
# Epoch 15/50
# 58/58 [==============================] - 13s 217ms/step - loss: 0.1710 - accuracy: 0.9332
# Epoch 16/50
# 58/58 [==============================] - 13s 218ms/step - loss: 0.1418 - accuracy: 0.9430
# Epoch 17/50
# 58/58 [==============================] - 13s 222ms/step - loss: 0.1268 - accuracy: 0.9501
# Epoch 18/50
# 58/58 [==============================] - 13s 223ms/step - loss: 0.1492 - accuracy: 0.9484
# Epoch 19/50
# 58/58 [==============================] - 13s 223ms/step - loss: 0.1338 - accuracy: 0.9506
# Epoch 20/50
# 58/58 [==============================] - 13s 223ms/step - loss: 0.0944 - accuracy: 0.9658
# Epoch 21/50
# 58/58 [==============================] - 13s 226ms/step - loss: 0.0933 - accuracy: 0.9691
# Epoch 22/50
# 58/58 [==============================] - 13s 226ms/step - loss: 0.0822 - accuracy: 0.9718
# Epoch 23/50
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0830 - accuracy: 0.9707
# Epoch 24/50
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0746 - accuracy: 0.9723
# Epoch 25/50
# 58/58 [==============================] - 13s 228ms/step - loss: 0.0736 - accuracy: 0.9723
# Epoch 26/50
# 58/58 [==============================] - 13s 229ms/step - loss: 0.0514 - accuracy: 0.9826
# Epoch 27/50
# 58/58 [==============================] - 13s 223ms/step - loss: 0.0545 - accuracy: 0.9783
# Epoch 28/50
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0608 - accuracy: 0.9783
# Epoch 29/50
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0391 - accuracy: 0.9886
# Epoch 30/50
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0342 - accuracy: 0.9886
# Epoch 31/50
# 58/58 [==============================] - 13s 224ms/step - loss: 0.0380 - accuracy: 0.9859
# Epoch 32/50
# 58/58 [==============================] - 13s 221ms/step - loss: 0.0291 - accuracy: 0.9908
# Epoch 33/50
# 58/58 [==============================] - 12s 213ms/step - loss: 0.0353 - accuracy: 0.9886
# Epoch 34/50
# 58/58 [==============================] - 12s 210ms/step - loss: 0.0347 - accuracy: 0.9891
# Epoch 35/50
# 58/58 [==============================] - 12s 212ms/step - loss: 0.0385 - accuracy: 0.9853
# Epoch 36/50
# 58/58 [==============================] - 12s 214ms/step - loss: 0.0443 - accuracy: 0.9853
# Epoch 37/50
# 58/58 [==============================] - 12s 213ms/step - loss: 0.0329 - accuracy: 0.9881
# Epoch 38/50
# 58/58 [==============================] - 12s 216ms/step - loss: 0.0356 - accuracy: 0.9891
# Epoch 39/50
# 58/58 [==============================] - 12s 213ms/step - loss: 0.0281 - accuracy: 0.9902
# Epoch 40/50
# 58/58 [==============================] - 12s 209ms/step - loss: 0.0235 - accuracy: 0.9919
# Epoch 41/50
# 58/58 [==============================] - 12s 213ms/step - loss: 0.0279 - accuracy: 0.9913
# Epoch 42/50
# 58/58 [==============================] - 12s 212ms/step - loss: 0.0435 - accuracy: 0.9870
# Epoch 43/50
# 58/58 [==============================] - 12s 210ms/step - loss: 0.0209 - accuracy: 0.9946
# Epoch 44/50
# 58/58 [==============================] - 12s 212ms/step - loss: 0.0195 - accuracy: 0.9951
# Epoch 45/50
# 58/58 [==============================] - 12s 214ms/step - loss: 0.0179 - accuracy: 0.9924
# Epoch 46/50
# 58/58 [==============================] - 12s 215ms/step - loss: 0.0165 - accuracy: 0.9962
# Epoch 47/50
# 58/58 [==============================] - 13s 217ms/step - loss: 0.0232 - accuracy: 0.9919
# Epoch 48/50
# 58/58 [==============================] - 12s 215ms/step - loss: 0.0228 - accuracy: 0.9935
# Epoch 49/50
# 58/58 [==============================] - 12s 214ms/step - loss: 0.0133 - accuracy: 0.9946
# Epoch 50/50
# 58/58 [==============================] - 8s 140ms/step - loss: 0.0312 - accuracy: 0.9886
# 15/15 [==============================] - 1s 22ms/step
#               precision    recall  f1-score     support
# 0              0.785408  0.843318  0.813333  217.000000
# 1              0.850877  0.795082  0.822034  244.000000
# accuracy       0.817787  0.817787  0.817787    0.817787
# macro avg      0.818142  0.819200  0.817684  461.000000
# weighted avg   0.820060  0.817787  0.817938  461.000000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.843318  0.915000  217.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.843318  0.843318  0.843318    0.843318
# macro avg      0.500000  0.421659  0.457500  217.000000
# weighted avg   1.000000  0.843318  0.915000  217.000000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.000000  0.000000  0.000000    0.000000
# 1              1.000000  0.795082  0.885845  244.000000
# accuracy       0.795082  0.795082  0.795082    0.795082
# macro avg      0.500000  0.397541  0.442922  244.000000
# weighted avg   1.000000  0.795082  0.885845  244.000000

# %%
lstmcnn = lstm_cnn()
preds = return_report(lstmcnn,50)
# Out:
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:tensorflow:From c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\keras\src\backend.py:6642: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 30)]              0
#
#  embedding_2 (Embedding)     (None, 30, 200)           378800
#
#  conv1d (Conv1D)             (None, 30, 32)            19232
#
#  max_pooling1d (MaxPooling1  (None, 15, 32)            0
#  D)
#
#  lstm_2 (LSTM)               (None, 100)               53200
#
#  dense_6 (Dense)             (None, 2)                 202
#
# =================================================================
# Total params: 451434 (1.72 MB)
# Trainable params: 72634 (283.73 KB)
# Non-trainable params: 378800 (1.45 MB)
# _________________________________________________________________
# None
# Epoch 1/50
# 58/58 [==============================] - 5s 17ms/step - loss: 0.6256 - accuracy: 0.6368
# Epoch 2/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.4718 - accuracy: 0.7866
# Epoch 3/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.4145 - accuracy: 0.8198
# Epoch 4/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.3660 - accuracy: 0.8599
# Epoch 5/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.3242 - accuracy: 0.8849
# Epoch 6/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.3022 - accuracy: 0.8931
# Epoch 7/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2621 - accuracy: 0.9121
# Epoch 8/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2835 - accuracy: 0.9017
# Epoch 9/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2409 - accuracy: 0.9218
# Epoch 10/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2375 - accuracy: 0.9229
# Epoch 11/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2355 - accuracy: 0.9213
# Epoch 12/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2135 - accuracy: 0.9332
# Epoch 13/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1940 - accuracy: 0.9425
# Epoch 14/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.2034 - accuracy: 0.9414
# Epoch 15/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1896 - accuracy: 0.9435
# Epoch 16/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1876 - accuracy: 0.9435
# Epoch 17/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1828 - accuracy: 0.9463
# Epoch 18/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1624 - accuracy: 0.9533
# Epoch 19/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1970 - accuracy: 0.9414
# Epoch 20/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1737 - accuracy: 0.9463
# Epoch 21/50
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1755 - accuracy: 0.9468
# Epoch 22/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1537 - accuracy: 0.9571
# Epoch 23/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1538 - accuracy: 0.9528
# Epoch 24/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1570 - accuracy: 0.9479
# Epoch 25/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1400 - accuracy: 0.9571
# Epoch 26/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1403 - accuracy: 0.9539
# Epoch 27/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1225 - accuracy: 0.9587
# Epoch 28/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1507 - accuracy: 0.9473
# Epoch 29/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1269 - accuracy: 0.9593
# Epoch 30/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.1221 - accuracy: 0.9582
# Epoch 31/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.1084 - accuracy: 0.9663
# Epoch 32/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0972 - accuracy: 0.9696
# Epoch 33/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0945 - accuracy: 0.9663
# Epoch 34/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0970 - accuracy: 0.9696
# Epoch 35/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0838 - accuracy: 0.9696
# Epoch 36/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0736 - accuracy: 0.9777
# Epoch 37/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0806 - accuracy: 0.9701
# Epoch 38/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0549 - accuracy: 0.9832
# Epoch 39/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0694 - accuracy: 0.9788
# Epoch 40/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0666 - accuracy: 0.9794
# Epoch 41/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0728 - accuracy: 0.9777
# Epoch 42/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0637 - accuracy: 0.9799
# Epoch 43/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0571 - accuracy: 0.9843
# Epoch 44/50
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0436 - accuracy: 0.9870
# Epoch 45/50
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0520 - accuracy: 0.9826
# Epoch 46/50
# 58/58 [==============================] - 1s 19ms/step - loss: 0.0422 - accuracy: 0.9891
# Epoch 47/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0641 - accuracy: 0.9810
# Epoch 48/50
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0492 - accuracy: 0.9859
# Epoch 49/50
# 58/58 [==============================] - 1s 18ms/step - loss: 0.0421 - accuracy: 0.9902
# Epoch 50/50
# 58/58 [==============================] - 1s 13ms/step - loss: 0.0419 - accuracy: 0.9881
# 15/15 [==============================] - 0s 3ms/step
#               precision    recall  f1-score    support
# 0              0.812500  0.778802  0.795294  217.00000
# 1              0.810277  0.840164  0.824950  244.00000
# accuracy       0.811280  0.811280  0.811280    0.81128
# macro avg      0.811388  0.809483  0.810122  461.00000
# weighted avg   0.811323  0.811280  0.810990  461.00000
# For inclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              1.000000  0.778802  0.875648  217.000000
# 1              0.000000  0.000000  0.000000    0.000000
# accuracy       0.778802  0.778802  0.778802    0.778802
# macro avg      0.500000  0.389401  0.437824  217.000000
# weighted avg   1.000000  0.778802  0.875648  217.000000
# For exclusions
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\awtfh\OneDrive - rwth-aachen.de\Desktop\Inclusion_Exclusion_Phrase_Mining-main\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# 0              0.000000  0.000000  0.000000    0.000000
# 1              1.000000  0.840164  0.913140  244.000000
# accuracy       0.840164  0.840164  0.840164    0.840164
# macro avg      0.500000  0.420082  0.456570  244.000000
# weighted avg   1.000000  0.840164  0.913140  244.000000

# %%
bilistm.save('task2_models/bi-lstm/model')
# Out:
# INFO:tensorflow:Assets written to: task2_models/bi-lstm/model\assets
# INFO:tensorflow:Assets written to: task2_models/bi-lstm/model\assets

# %% [markdown]
# ### Simple Classifiers

# %%
tag2idx = {t: i for i, t in enumerate(tags)}
max_len = 30
emb_dim = len(vec_model['the'])
X = []
y = []

for sent in sentences:
    vec = np.zeros((30,emb_dim))
    for i, word in enumerate(sent):
        if word in vec_model:
            vec[i,:] = vec_model[word]
    X.append(vec)
X = np.array(X)
y = np.array([tag2idx[tg] for tg in labels])
y = [[y[i],typs[i]] for i in range(len(y))]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
y_train = np.array([lab[0] for lab in y_train])
typ_test = [lab[1] for lab in y_test]
y_test = np.array([lab[0] for lab  in y_test])
X_train = X_train.reshape((X_train.shape[0],max_len*emb_dim))
X_test = X_test.reshape((X_test.shape[0],max_len*emb_dim))

# %%
from sklearn.svm import SVC

# %%
clf = SVC(kernel='poly')
clf.fit(X_train,y_train)
pred = clf.predict(X_test)
full_results(y_test,pred)

# %%
from sklearn.tree import DecisionTreeClassifier
